# %%
#@title INSTALL PACKAGES
# !pip install statsforecast mlforecast neuralforecast dask-expr
# Out:
# Collecting statsforecast
#   Downloading statsforecast-1.7.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (28 kB)
# Collecting mlforecast
#   Downloading mlforecast-0.13.5-py3-none-any.whl.metadata (12 kB)
# Collecting neuralforecast
#   Downloading neuralforecast-1.7.5-py3-none-any.whl.metadata (14 kB)
# Collecting dask-expr
#   Downloading dask_expr-1.1.16-py3-none-any.whl.metadata (2.5 kB)
# Collecting cloudpickle (from statsforecast)
#   Downloading cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting coreforecast>=0.0.12 (from statsforecast)
#   Downloading coreforecast-0.0.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting numba>=0.55.0 (from statsforecast)
#   Downloading numba-0.60.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy>=1.21.6 in /home/codespace/.local/lib/python3.12/site-packages (from statsforecast) (2.1.1)
# Requirement already satisfied: pandas>=1.3.5 in /home/codespace/.local/lib/python3.12/site-packages (from statsforecast) (2.2.3)
# Requirement already satisfied: scipy>=1.7.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsforecast) (1.14.1)
# Collecting statsmodels>=0.13.2 (from statsforecast)
#   Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting tqdm (from statsforecast)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting fugue>=0.8.1 (from statsforecast)
#   Downloading fugue-0.9.1-py3-none-any.whl.metadata (18 kB)
# Collecting utilsforecast>=0.1.4 (from statsforecast)
#   Downloading utilsforecast-0.2.5-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: threadpoolctl>=3 in /home/codespace/.local/lib/python3.12/site-packages (from statsforecast) (3.5.0)
# Requirement already satisfied: fsspec in /home/codespace/.local/lib/python3.12/site-packages (from mlforecast) (2024.2.0)
# Collecting optuna (from mlforecast)
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from mlforecast) (24.1)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.12/site-packages (from mlforecast) (1.5.2)
# Collecting window-ops (from mlforecast)
#   Downloading window_ops-0.0.15-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: torch>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from neuralforecast) (2.4.1+cpu)
# Collecting pytorch-lightning>=2.0.0 (from neuralforecast)
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting ray>=2.2.0 (from ray[tune]>=2.2.0->neuralforecast)
#   Downloading ray-2.37.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting dask==2024.10.0 (from dask-expr)
#   Downloading dask-2024.10.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting pyarrow>=14.0.1 (from dask-expr)
#   Downloading pyarrow-17.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting click>=8.1 (from dask==2024.10.0->dask-expr)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting partd>=1.4.0 (from dask==2024.10.0->dask-expr)
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from dask==2024.10.0->dask-expr) (6.0.2)
# Collecting toolz>=0.10.0 (from dask==2024.10.0->dask-expr)
#   Downloading toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting triad>=0.9.7 (from fugue>=0.8.1->statsforecast)
#   Downloading triad-0.9.8-py3-none-any.whl.metadata (6.3 kB)
# Collecting adagio>=0.2.4 (from fugue>=0.8.1->statsforecast)
#   Downloading adagio-0.2.6-py3-none-any.whl.metadata (1.8 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.55.0->statsforecast)
#   Downloading llvmlite-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting numpy>=1.21.6 (from statsforecast)
#   Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.3.5->statsforecast) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.3.5->statsforecast) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.3.5->statsforecast) (2024.2)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading torchmetrics-1.5.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.9.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading lightning_utilities-0.11.8-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.12/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.13.1)
# Requirement already satisfied: jsonschema in /home/codespace/.local/lib/python3.12/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (4.23.0)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast)
#   Downloading msgpack-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting protobuf!=3.19.5,>=3.15.3 (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast)
#   Downloading protobuf-5.28.2-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting aiosignal (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting frozenlist (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast)
#   Downloading frozenlist-1.4.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2.32.3)
# Collecting tensorboardX>=1.9 (from ray[tune]>=2.2.0->neuralforecast)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting patsy>=0.5.6 (from statsmodels>=0.13.2->statsforecast)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.12/site-packages (from torch>=2.0.0->neuralforecast) (1.12)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.12/site-packages (from torch>=2.0.0->neuralforecast) (3.2.1)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.12/site-packages (from torch>=2.0.0->neuralforecast) (3.1.4)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from torch>=2.0.0->neuralforecast) (75.1.0)
# Collecting alembic>=1.5.0 (from optuna->mlforecast)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna->mlforecast)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting sqlalchemy>=1.3.0 (from optuna->mlforecast)
#   Downloading SQLAlchemy-2.0.36-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: joblib>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn->mlforecast) (1.4.2)
# Collecting Mako (from alembic>=1.5.0->optuna->mlforecast)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading aiohttp-3.10.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Collecting locket (from partd>=1.4.0->dask==2024.10.0->dask-expr)
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->statsforecast) (1.16.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna->mlforecast)
#   Downloading greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting numpy>=1.21.6 (from statsforecast)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting fs (from triad>=0.9.7->fugue>=0.8.1->statsforecast)
#   Downloading fs-2.4.16-py2.py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->neuralforecast) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2024.8.30)
# Requirement already satisfied: mpmath>=0.19 in /home/codespace/.local/lib/python3.12/site-packages (from sympy->torch>=2.0.0->neuralforecast) (1.3.0)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting yarl<2.0,>=1.12.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading yarl-1.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (63 kB)
# Collecting appdirs~=1.4.3 (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting propcache>=0.2.0 (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading propcache-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Downloading statsforecast-1.7.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (315 kB)
# Downloading mlforecast-0.13.5-py3-none-any.whl (71 kB)
# Downloading neuralforecast-1.7.5-py3-none-any.whl (254 kB)
# Downloading dask_expr-1.1.16-py3-none-any.whl (243 kB)
# Downloading dask-2024.10.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.1 MB/s eta 0:00:00
# Downloading cloudpickle-3.1.0-py3-none-any.whl (22 kB)
# Downloading coreforecast-0.0.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (274 kB)
# Downloading fugue-0.9.1-py3-none-any.whl (278 kB)
# Downloading numba-0.60.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 30.4 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 58.7 MB/s eta 0:00:00:00:01:01
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 10.1 MB/s eta 0:00:00
# Downloading ray-2.37.0-cp312-cp312-manylinux2014_x86_64.whl (65.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 MB 38.3 MB/s eta 0:00:0000:0100:01m
# Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 72.2 MB/s eta 0:00:00
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Downloading utilsforecast-0.2.5-py3-none-any.whl (41 kB)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
# Downloading window_ops-0.0.15-py3-none-any.whl (15 kB)
# Downloading adagio-0.2.6-py3-none-any.whl (19 kB)
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading lightning_utilities-0.11.8-py3-none-any.whl (26 kB)
# Downloading llvmlite-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 64.9 MB/s eta 0:00:00:00:01
# Downloading msgpack-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (401 kB)
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Downloading protobuf-5.28.2-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
# Downloading SQLAlchemy-2.0.36-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 42.0 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
# Downloading torchmetrics-1.5.0-py3-none-any.whl (890 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.5/890.5 kB 9.7 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 64.6 MB/s eta 0:00:00:00:01
# Downloading triad-0.9.8-py3-none-any.whl (62 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading aiohttp-3.10.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.1 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (613 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 7.9 MB/s eta 0:00:00
# Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
# Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
# Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
# Downloading yarl-1.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (336 kB)
# Downloading propcache-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (248 kB)
# Installing collected packages: appdirs, tqdm, toolz, protobuf, propcache, numpy, multidict, msgpack, Mako, locket, llvmlite, lightning-utilities, greenlet, fs, frozenlist, colorlog, cloudpickle, click, aiohappyeyeballs, yarl, tensorboardX, sqlalchemy, pyarrow, patsy, partd, numba, coreforecast, aiosignal, window-ops, utilsforecast, triad, torchmetrics, statsmodels, dask, alembic, aiohttp, ray, optuna, dask-expr, adagio, pytorch-lightning, mlforecast, fugue, statsforecast, neuralforecast
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.1
#     Uninstalling numpy-2.1.1:
#       Successfully uninstalled numpy-2.1.1
# Successfully installed Mako-1.3.6 adagio-0.2.6 aiohappyeyeballs-2.4.3 aiohttp-3.10.10 aiosignal-1.3.1 alembic-1.13.3 appdirs-1.4.4 click-8.1.7 cloudpickle-3.1.0 colorlog-6.8.2 coreforecast-0.0.13.1 dask-2024.10.0 dask-expr-1.1.16 frozenlist-1.4.1 fs-2.4.16 fugue-0.9.1 greenlet-3.1.1 lightning-utilities-0.11.8 llvmlite-0.43.0 locket-1.0.0 mlforecast-0.13.5 msgpack-1.1.0 multidict-6.1.0 neuralforecast-1.7.5 numba-0.60.0 numpy-1.26.4 optuna-4.0.0 partd-1.4.2 patsy-0.5.6 propcache-0.2.0 protobuf-5.28.2 pyarrow-17.0.0 pytorch-lightning-2.4.0 ray-2.37.0 sqlalchemy-2.0.36 statsforecast-1.7.8 statsmodels-0.14.4 tensorboardX-2.6.2.2 toolz-1.0.0 torchmetrics-1.5.0 tqdm-4.66.5 triad-0.9.8 utilsforecast-0.2.5 window-ops-0.0.15 yarl-1.16.0

# %%
# !pip install lightgbm

# %%
#@title IMPORT LIBRARY
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

from tqdm import tqdm
from utilsforecast.plotting import plot_series

from statsforecast.core import StatsForecast
from statsforecast.models import AutoARIMA, Naive

from statsforecast.models import *

from mlforecast import MLForecast

import lightgbm as lgb
from mlforecast.target_transforms import Differences
from mlforecast.lag_transforms import ExpandingMean, RollingMean, ExpandingMax, ExpandingMin, ExpandingStd

from utilsforecast.evaluation import evaluate
from utilsforecast.losses import rmse, mse
from mlforecast.utils import generate_daily_series, generate_prices_for_series

os.environ['NIXTLA_ID_AS_COL'] = '1'
pd.options.mode.chained_assignment = None

# %%
#@title BASE FUNCTIONS
def retrieve_data(sales_dir, price_dir):
    sales_raw = pd.read_csv(sales_dir)
    price_raw = pd.read_csv(price_dir)

    cols = sales_raw.columns
    dates = cols[3:]

    sales = sales_raw.melt(id_vars=cols[:3], var_name='Date', value_vars=dates, value_name='Sales')
    price = price_raw.melt(id_vars=cols[:3], var_name='Date', value_vars=dates, value_name='Sales')

    sales['unique_id'] = sales['Client'].astype(str) + '-' + sales['Warehouse'].astype(str) + '-' + sales['Product'].astype(str)
    price['unique_id'] = price['Client'].astype(str) + '-' + price['Warehouse'].astype(str) + '-' + price['Product'].astype(str)

    sales = sales.rename(columns={'Date': 'ds', 'Sales': 'y'})
    price = price.rename(columns={'Date': 'ds', 'Sales': 'price'})
    sales['ds'] = pd.to_datetime(sales['ds'])
    price['ds'] = pd.to_datetime(price['ds'])

    return sales, price

def mean_impute(series):
    series = series.fillna(series.rolling(window=3, min_periods=1, center=True).mean())
    series = series.ffill()
    series = series.bfill()

    return series

# %%
#@title VARIABLE SETTINGS

sales_dir = '../phase_0/Phase 0 - Sales.csv'
price_dir = '../phase_0/Phase 0 - Price.csv'
sales, price = retrieve_data(sales_dir, price_dir)
price['price'] = mean_impute(price['price'])

freq = 'W-MON'
horizon=13
season_length = 52

# %%
sales_dir = '../phase_1/Phase 1 - Sales.csv'
price_dir = '../phase_1/Phase 1 - Price.csv'

sales_phase_1, price = retrieve_data(sales_dir, price_dir)

sales_phase_1
# Out:
#         Client  Warehouse  Product         ds     y     unique_id
# 0            0          1      367 2023-10-09   1.0       0-1-367
# 1            0          1      639 2023-10-09   5.0       0-1-639
# 2            0          1      655 2023-10-09   6.0       0-1-655
# 3            0          1     1149 2023-10-09   1.0      0-1-1149
# 4            0          1     1485 2023-10-09   0.0      0-1-1485
# ...        ...        ...      ...        ...   ...           ...
# 195684      46        318    13485 2024-01-01   0.0  46-318-13485
# 195685      46        318    13582 2024-01-01  67.0  46-318-13582
# 195686      46        318    13691 2024-01-01   2.0  46-318-13691
# 195687      46        318    13946 2024-01-01   0.0  46-318-13946
# 195688      46        318    14294 2024-01-01   3.0  46-318-14294
#
# [195689 rows x 6 columns]

# %%
sales = pd.concat([sales, sales_phase_1], axis=0)
sales
# Out:
#         Client  Warehouse  Product         ds     y     unique_id
# 0            0          1      367 2020-07-06   7.0       0-1-367
# 1            0          1      639 2020-07-06   0.0       0-1-639
# 2            0          1      655 2020-07-06  21.0       0-1-655
# 3            0          1     1149 2020-07-06   7.0      0-1-1149
# 4            0          1     1485 2020-07-06   0.0      0-1-1485
# ...        ...        ...      ...        ...   ...           ...
# 195684      46        318    13485 2024-01-01   0.0  46-318-13485
# 195685      46        318    13582 2024-01-01  67.0  46-318-13582
# 195686      46        318    13691 2024-01-01   2.0  46-318-13691
# 195687      46        318    13946 2024-01-01   0.0  46-318-13946
# 195688      46        318    14294 2024-01-01   3.0  46-318-14294
#
# [2754699 rows x 6 columns]

# %%
#@title THETA MODEL
sf = StatsForecast(
    # models=[Theta(season_length=52, decomposition_type="additive")],
    models=[DynamicTheta(season_length=52, decomposition_type="additive")],
    # models=[ADIDA()],
    freq='W-MON',
    fallback_model = Naive(),
    n_jobs=-1,
)

# forecast_df = sf.forecast(df=sales, h=13)
sf.fit(df=sales)
forecast_df = sf.predict(h=horizon)

# %%
#@title MFLES MODEL
seasonal_period = 52

config = {
    'seasonality_weights': [True, False],
    'smoother': [True, False],
    'ma': [52, 12, 8, 4, None]
}

# model = AutoMFLES(season_length=52, test_size=17, n_windows=3, metric='mse', config=config)
model = AutoMFLES(season_length=52, test_size=13, n_windows=4, metric='mse', config=config)

sf = StatsForecast(
    models=[model],
    fallback_model = Naive(),
    freq='W-MON',
    n_jobs=-1,
    verbose=True
)

sf.fit(df = sales)

# Generate test predictions
forecast_df = sf.predict(h=horizon)

# %%
#@title MAKE SUBMISSION
def make_submission(forecast_df):
    submission = forecast_df.copy()
    values = forecast_df.columns[-1]

    submission[values] = submission[values].clip(0)
    submission[['Client', 'Warehouse', 'Product']] = submission['unique_id'].str.split('-', expand=True)
    submission = submission.drop(columns='unique_id')
    submission['ds'] = submission['ds'].astype(str)

    submission = submission.pivot(columns='ds', index=['Client', 'Warehouse', 'Product'], values=values).reset_index()
    submission[['Client', 'Warehouse', 'Product']] = submission[['Client', 'Warehouse', 'Product']].astype(int)
    submission = submission.sort_values(['Client', 'Warehouse', 'Product'])

    # submission = submission.map(lambda x: x if x>=0 else 0)

    current_datetime = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    submission.to_csv('../mfles2.csv', index=None)

    return submission

submission = make_submission(forecast_df)
