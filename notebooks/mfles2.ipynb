# %%
#@title INSTALL PACKAGES
# !pip install statsforecast mlforecast neuralforecast dask-expr

# %%
#@title IMPORT LIBRARY
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

from tqdm import tqdm
from utilsforecast.plotting import plot_series

from statsforecast.core import StatsForecast
from statsforecast.models import AutoARIMA, Naive

from statsforecast.models import *

from mlforecast import MLForecast

import lightgbm as lgb
from mlforecast.target_transforms import Differences
from mlforecast.lag_transforms import ExpandingMean, RollingMean, ExpandingMax, ExpandingMin, ExpandingStd

from utilsforecast.evaluation import evaluate
from utilsforecast.losses import rmse, mse
from mlforecast.utils import generate_daily_series, generate_prices_for_series

os.environ['NIXTLA_ID_AS_COL'] = '1'
pd.options.mode.chained_assignment = None

# %%
#@title BASE FUNCTIONS
def retrieve_data(sales_dir, price_dir):
    sales_raw = pd.read_csv(sales_dir)
    price_raw = pd.read_csv(price_dir)

    cols = sales_raw.columns
    dates = cols[3:]

    sales = sales_raw.melt(id_vars=cols[:3], var_name='Date', value_vars=dates, value_name='Sales')
    price = price_raw.melt(id_vars=cols[:3], var_name='Date', value_vars=dates, value_name='Sales')

    sales['unique_id'] = sales['Client'].astype(str) + '-' + sales['Warehouse'].astype(str) + '-' + sales['Product'].astype(str)
    price['unique_id'] = price['Client'].astype(str) + '-' + price['Warehouse'].astype(str) + '-' + price['Product'].astype(str)

    sales = sales.rename(columns={'Date': 'ds', 'Sales': 'y'})
    price = price.rename(columns={'Date': 'ds', 'Sales': 'price'})
    sales['ds'] = pd.to_datetime(sales['ds'])
    price['ds'] = pd.to_datetime(price['ds'])

    return sales, price

def mean_impute(series):
    series = series.fillna(series.rolling(window=3, min_periods=1, center=True).mean())
    series = series.ffill()
    series = series.bfill()

    return series

def nixtla_evaluate(df):
    result_dict = {}
    train = df['y']
    models = [df.columns[-1]]

    for model in models:
        test = df[model]
        abs_err = np.nansum(abs(train - test))
        err = np.nansum((train - test))
        score = abs_err + abs(err)
        score /= test.sum().sum()
        result_dict[model] = score

    return pd.DataFrame([result_dict])

# %%
#@title VARIABLE SETTINGS

sales_dir = '/content/drive/MyDrive/sales-forecasting/Phase 0 - Sales.csv'
price_dir = '/content/drive/MyDrive/sales-forecasting/Phase 0 - Price.csv'
sales, price = retrieve_data(sales_dir, price_dir)
price['price'] = mean_impute(price['price'])

freq = 'W-MON'
horizon=13
season_length = 52

# %%
sales_dir = '/content/drive/MyDrive/sales-forecasting/phase_1/Phase 1 - Sales.csv'
price_dir = '/content/drive/MyDrive/sales-forecasting/phase_1/Phase 1 - Price.csv'

sales_phase_1, price = retrieve_data(sales_dir, price_dir)

sales_phase_1
# Out:
#         Client  Warehouse  Product         ds     y     unique_id
# 0            0          1      367 2023-10-09   1.0       0-1-367
# 1            0          1      639 2023-10-09   5.0       0-1-639
# 2            0          1      655 2023-10-09   6.0       0-1-655
# 3            0          1     1149 2023-10-09   1.0      0-1-1149
# 4            0          1     1485 2023-10-09   0.0      0-1-1485
# ...        ...        ...      ...        ...   ...           ...
# 195684      46        318    13485 2024-01-01   0.0  46-318-13485
# 195685      46        318    13582 2024-01-01  67.0  46-318-13582
# 195686      46        318    13691 2024-01-01   2.0  46-318-13691
# 195687      46        318    13946 2024-01-01   0.0  46-318-13946
# 195688      46        318    14294 2024-01-01   3.0  46-318-14294
#
# [195689 rows x 6 columns]

# %%
sales = pd.concat([sales, sales_phase_1], axis=0)
sales
# Out:
#         Client  Warehouse  Product         ds     y     unique_id
# 0            0          1      367 2020-07-06   7.0       0-1-367
# 1            0          1      639 2020-07-06   0.0       0-1-639
# 2            0          1      655 2020-07-06  21.0       0-1-655
# 3            0          1     1149 2020-07-06   7.0      0-1-1149
# 4            0          1     1485 2020-07-06   0.0      0-1-1485
# ...        ...        ...      ...        ...   ...           ...
# 195684      46        318    13485 2024-01-01   0.0  46-318-13485
# 195685      46        318    13582 2024-01-01  67.0  46-318-13582
# 195686      46        318    13691 2024-01-01   2.0  46-318-13691
# 195687      46        318    13946 2024-01-01   0.0  46-318-13946
# 195688      46        318    14294 2024-01-01   3.0  46-318-14294
#
# [2754699 rows x 6 columns]

# %%
#@title THETA MODEL
sf = StatsForecast(
    # models=[Theta(season_length=52, decomposition_type="additive")],
    models=[DynamicTheta(season_length=52, decomposition_type="additive")],
    # models=[ADIDA()],
    freq='W-MON',
    fallback_model = Naive(),
    n_jobs=-1,
)

# forecast_df = sf.forecast(df=sales, h=13)
sf.fit(df=sales)
forecast_df = sf.predict(h=horizon)

# %%
crossvalidation_df = sf.cross_validation(df=sales, h=horizon, step_size=horizon, n_windows=4)
nixtla_evaluate(crossvalidation_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/stattools.py:702: RuntimeWarning: invalid value encountered in divide
#   acf = avf[: nlags + 1] / avf[0]
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/stattools.py:702: RuntimeWarning: invalid value encountered in divide
#   acf = avf[: nlags + 1] / avf[0]
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/stattools.py:702: RuntimeWarning: invalid value encountered in divide
#   acf = avf[: nlags + 1] / avf[0]
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/stattools.py:702: RuntimeWarning: invalid value encountered in divide
#   acf = avf[: nlags + 1] / avf[0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/statsforecast/core.py in _cross_validation_parallel(self, h, test_size, step_size, input_size, fitted, level, refit, target_col)
#    1329                 futures.append(future)
# -> 1330             out = [f.get() for f in futures]
#    1331             fcsts = [d["forecasts"] for d in out]
#
# /usr/local/lib/python3.10/dist-packages/statsforecast/core.py in <listcomp>(.0)
#    1329                 futures.append(future)
# -> 1330             out = [f.get() for f in futures]
#    1331             fcsts = [d["forecasts"] for d in out]
#
# /usr/lib/python3.10/multiprocessing/pool.py in get(self, timeout)
#     767     def get(self, timeout=None):
# --> 768         self.wait(timeout)
#     769         if not self.ready():
#
# /usr/lib/python3.10/multiprocessing/pool.py in wait(self, timeout)
#     764     def wait(self, timeout=None):
# --> 765         self._event.wait(timeout)
#     766
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     606             if not signaled:
# --> 607                 signaled = self._cond.wait(timeout)
#     608             return signaled
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b7df8c321d8c> in <cell line: 1>()
# ----> 1 crossvalidation_df = sf.cross_validation(df=sales, h=horizon, step_size=horizon, n_windows=4)
#       2 nixtla_evaluate(crossvalidation_df)
#
# /usr/local/lib/python3.10/dist-packages/statsforecast/core.py in cross_validation(self, h, df, n_windows, step_size, test_size, input_size, level, fitted, refit, sort_df, prediction_intervals, id_col, time_col, target_col)
#    1696     ):
#    1697         if self._is_native(df=df):
# -> 1698             return super().cross_validation(
#    1699                 h=h,
#    1700                 df=df,
#
# /usr/local/lib/python3.10/dist-packages/statsforecast/core.py in cross_validation(self, h, df, n_windows, step_size, test_size, input_size, level, fitted, refit, sort_df, prediction_intervals, id_col, time_col, target_col)
#    1105             )
#    1106         else:
# -> 1107             res_fcsts = self._cross_validation_parallel(
#    1108                 h=h,
#    1109                 test_size=test_size,
#
# /usr/local/lib/python3.10/dist-packages/statsforecast/core.py in _cross_validation_parallel(self, h, test_size, step_size, input_size, fitted, level, refit, target_col)
#    1307         # compute parallel forecasts
#    1308         result = {}
# -> 1309         with Pool(self.n_jobs, **pool_kwargs) as executor:
#    1310             futures = []
#    1311             for ga in gas:
#
# /usr/lib/python3.10/multiprocessing/pool.py in __exit__(self, exc_type, exc_val, exc_tb)
#     737
#     738     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 739         self.terminate()
#     740
#     741 #
#
# /usr/lib/python3.10/multiprocessing/pool.py in terminate(self)
#     655         util.debug('terminating pool')
#     656         self._state = TERMINATE
# --> 657         self._terminate()
#     658
#     659     def join(self):
#
# /usr/lib/python3.10/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     222                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     223                           self._callback, self._args, self._kwargs)
# --> 224                 res = self._callback(*self._args, **self._kwargs)
#     225             self._weakref = self._callback = self._args = \
#     226                             self._kwargs = self._key = None
#
# /usr/lib/python3.10/multiprocessing/pool.py in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     730                     # worker has not yet exited
#     731                     util.debug('cleaning up worker %d' % p.pid)
# --> 732                     p.join()
#     733
#     734     def __enter__(self):
#
# /usr/lib/python3.10/multiprocessing/process.py in join(self, timeout)
#     147         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148         assert self._popen is not None, 'can only join a started process'
# --> 149         res = self._popen.wait(timeout)
#     150         if res is not None:
#     151             _children.discard(self)
#
# /usr/lib/python3.10/multiprocessing/popen_fork.py in wait(self, timeout)
#      41                     return None
#      42             # This shouldn't block if wait() returned successfully.
# ---> 43             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44         return self.returncode
#      45
#
# /usr/lib/python3.10/multiprocessing/popen_fork.py in poll(self, flag)
#      25         if self.returncode is None:
#      26             try:
# ---> 27                 pid, sts = os.waitpid(self.pid, flag)
#      28             except OSError:
#      29                 # Child process not yet created. See #1731717
#
# KeyboardInterrupt:

# %%
#@title MFLES MODEL
seasonal_period = 52

config = {
    'seasonality_weights': [True, False],
    'smoother': [True, False],
    'ma': [52, 12, 8, 4, None]
}

# model = AutoMFLES(season_length=52, test_size=17, n_windows=3, metric='mse', config=config)
model = AutoMFLES(season_length=52, test_size=13, n_windows=4, metric='mse', config=config)

sf = StatsForecast(
    models=[model],
    fallback_model = Naive(),
    freq='W-MON',
    n_jobs=-1,
    verbose=True
)

sf.fit(df = sales)

# Generate test predictions
forecast_df = sf.predict(h=horizon)

# %%
#@title MAKE SUBMISSION
def make_submission(forecast_df):
    submission = forecast_df.copy()
    values = forecast_df.columns[-1]

    submission[values] = submission[values].clip(0)
    submission[['Client', 'Warehouse', 'Product']] = submission['unique_id'].str.split('-', expand=True)
    submission = submission.drop(columns='unique_id')
    submission['ds'] = submission['ds'].astype(str)

    submission = submission.pivot(columns='ds', index=['Client', 'Warehouse', 'Product'], values=values).reset_index()
    submission[['Client', 'Warehouse', 'Product']] = submission[['Client', 'Warehouse', 'Product']].astype(int)
    submission = submission.sort_values(['Client', 'Warehouse', 'Product'])

    # submission = submission.map(lambda x: x if x>=0 else 0)

    current_datetime = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    submission.to_csv(f'{current_datetime}_{values}.csv', index=None)

    return submission

submission = make_submission(forecast_df)
